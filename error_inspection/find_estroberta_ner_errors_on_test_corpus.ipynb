# %% [markdown]
# ## Inspect EstRoBERTa's NER errors on the test set

# %%
import os, os.path, re

from estnltk import Text
from estnltk.converters import json_to_text

test_data_dir  = '../data/test'

output_fname = 'estroberta_ner_errors_test_corpus.txt'

full_tagset = ['PER', 'LOC_ORG', 'LOC', 'ORG', 'MISC']

assert os.path.exists(test_data_dir)

# %%
# Location of the best BERT model
bert_models_dir = '../bert_models'
bertner_model_location = os.path.join( bert_models_dir, 'model_est-roberta_10_bs16_lr5e-05_ep8' )
assert os.path.exists(bertner_model_location)

# %%
# Allow relative imports from the root dir
import sys
sys.path.insert(0, '..')

# Load the best model
from bert_ner_tagger import BertNERTagger
bert_ner_tagger_phrases = BertNERTagger(bertner_model_location, bertner_model_location, output_layer='ner',
                                        token_level=False, do_lower_case=False, use_fast=False)

# Load preprocessing utils
from data_preprocessing import TokenizationPreprocessorFixed

# %%
from estnltk.converters import json_to_text
from ner_diff_utils import NerDiffFinder
from tqdm import tqdm

def _text_snippet( text_obj, start, end ):
    '''Takes a snippet out of the text, assuring that text boundaries are not exceeded.
       Also, makes newline character explicit in text by replacing it with '\\n'.
    '''
    start = 0 if start < 0 else start
    start = len(text_obj.text) if start > len(text_obj.text) else start
    end   = len(text_obj.text) if end > len(text_obj.text)   else end
    end   = 0 if end < 0 else end
    snippet = text_obj.text[start:end]
    snippet = snippet.replace('\n', '\\n')
    return snippet

def _format_grouped_diff( group, layer_a='gold_ner_flat', layer_b='ner_flat', label_attr='__label', N=40 ):
    '''Adds textual context (N chars left and right) to the given group (of annotation differences) 
       and returns formatted difference lines (list of strings).
    '''
    assert 'gold' in layer_a
    max_len = max(len(layer_a), len(layer_b))
    output_lines = []
    conflict_loc = group['__loc']
    text_obj = None
    if group[layer_a]:
        text_obj = group[layer_a][0].text_object
    else:
        text_obj = group[layer_b][0].text_object
    output_a = [' gold:  ']
    output_b = [' auto:  ']
    a_spans = [(a.start, a.end) for a in group[layer_a]]
    b_spans = [(b.start, b.end) for b in group[layer_b]]
    before_a = '...'+_text_snippet( text_obj, conflict_loc[0]-N, conflict_loc[0] )
    before_b = '...'+_text_snippet( text_obj, conflict_loc[0]-N, conflict_loc[0] )
    if a_spans:
        before_a = '...'+_text_snippet( text_obj, a_spans[0][0]-N, a_spans[0][0] )
    if b_spans:
        before_b = '...'+_text_snippet( text_obj, b_spans[0][0]-N, b_spans[0][0] )
    output_a.append(before_a)
    output_b.append(before_b)
    last_span = None
    for aid, (start,end) in enumerate(a_spans):
        annotation = group[layer_a][aid].annotations[0]
        if last_span:
            if last_span[1] != start:
                output_a.append( _text_snippet( text_obj,last_span[1],start ) )
        output_a.append( '{'+_text_snippet( text_obj,start,end )+'} /'+annotation[label_attr] )
        last_span = (start,end)
    last_span = None
    for bid, (start,end) in enumerate(b_spans):
        annotation = group[layer_b][bid].annotations[0]
        if last_span:
            if last_span[1] != start:
                output_b.append( _text_snippet( text_obj,last_span[1],start ) )
        output_b.append( '{'+_text_snippet( text_obj,start,end )+'} /'+annotation[label_attr] )
        last_span = (start,end)
    after_a = _text_snippet( text_obj, conflict_loc[0], conflict_loc[1]+N )+'...'
    after_b = _text_snippet( text_obj, conflict_loc[0], conflict_loc[1]+N )+'...'
    if a_spans:
        after_a = _text_snippet( text_obj, a_spans[-1][1], a_spans[-1][1]+N )+'...'
    if b_spans:
        after_b = _text_snippet( text_obj, b_spans[-1][1], b_spans[-1][1]+N )+'...'
    output_a.append(after_a)
    output_b.append(after_b)
    output_lines.append( ''.join(output_a) )
    output_lines.append( ''.join(output_b) )
    return output_lines

def write_out( line, fp ):
    '''Writes to file and stdout.'''
    if not isinstance(line, str):
        line = str(line)
    print(line)
    fp.write(line+'\n')

def evaluate_on_auto_morph_preprocess( tagger, input_dir, input_files, output_file ):
    '''Uses (BertNER)Tagger to annotate input_files in the input_dir and compares automatic 
       NE annotations to gold standard NE annotations available in files. 
       Groups annotation differences into categories (such as 'missing', 'extra', 'wrong_label'), 
       adds context to each difference, and finally outputs categorized differences to standard 
       output stream and to output_file.
    '''
    ner_diff_finder = NerDiffFinder('gold_ner', 
                                    'ner', 
                                     old_layer_attr='nertag', 
                                     new_layer_attr='nertag')
    preprocessor = TokenizationPreprocessorFixed()
    doc_count = 0
    grouped_errors = dict()
    for fname in tqdm( os.listdir(input_dir) ):
        if fname.endswith('.json') and fname in input_files:
            text_obj = json_to_text(file=os.path.join(input_dir, fname))
            preprocessor.preprocess( text_obj )
            text_obj.meta['fname'] = fname.replace('.json', '')
            tagger.tag(text_obj)
            #print( len( text_obj['ner'] ) )
            diff_layer, formatted_diffs_str, grouped_diffs, total_diff_gaps = \
                ner_diff_finder.find_difference( text_obj, fname )
            for g_diff in grouped_diffs:
                g_diff['__status'] = None
                g_diff['__entity'] = ''
                if len(g_diff['ner_flat']) == 0 and len(g_diff['gold_ner_flat']) > 0:
                    g_diff['__status'] = 'missing'
                    g_diff['__entity'] = g_diff['gold_ner_flat'][0].text
                elif len(g_diff['ner_flat']) > 0 and len(g_diff['gold_ner_flat']) == 0:
                    g_diff['__status'] = 'extra'
                    g_diff['__entity'] = g_diff['ner_flat'][0].text
                elif len(g_diff['ner_flat']) == 1 and len(g_diff['gold_ner_flat']) == 1:
                    span_a = g_diff['gold_ner_flat'][0]
                    span_b = g_diff['ner_flat'][0]
                    span_a_label = span_a.annotations[0]['__label']
                    span_b_label = span_b.annotations[0]['__label']
                    g_diff['__entity'] = g_diff['gold_ner_flat'][0].text
                    if span_a.start == span_b.start and span_a.end == span_b.end:
                        assert span_a_label != span_b_label
                        g_diff['__status'] = 'wrong_label'
                    else:
                        if span_a_label != span_b_label:
                            g_diff['__status'] = 'wrong_boundaries + wrong_label'
                        else:
                            g_diff['__status'] = 'wrong_boundaries'
                else:
                    g_diff['__entity'] = g_diff['gold_ner_flat'][0].text
                    g_diff['__status'] = 'wrong_boundaries'
                g_diff['__output'] = _format_grouped_diff( g_diff )
                g_diff['__file'] = text_obj.meta['fname']
                assert g_diff['__status'] is not None
                err_type = g_diff['__status']
                if err_type not in grouped_errors:
                    grouped_errors[ err_type ] = []
                grouped_errors[ err_type ].append( g_diff )
                #print( g_diff )
            doc_count += 1
            #print( formatted_diffs_str )
            #if doc_count > 5:
            #    break
    with open(output_file, 'w', encoding='utf-8') as out_f:
        write_out( '', out_f )
        write_out( grouped_errors.keys(), out_f )
        write_out( '', out_f )
        for err_type in sorted(grouped_errors.keys(), key=lambda x : len(grouped_errors[x]), reverse=True):
            write_out( '='*70, out_f )
            write_out( err_type+' ('+str(len(grouped_errors[err_type]))+')', out_f )
            write_out( '='*70, out_f )
            prev_fname = None
            for g_diff in sorted(grouped_errors[err_type], key=lambda x:x['__entity']):
                snippet = g_diff['__output'][0]+' | '+g_diff['__file']
                write_out( snippet, out_f )
                if len(g_diff['__output']) > 0:
                    for out in  g_diff['__output'][1:]:
                        write_out( out, out_f )
                write_out( '', out_f )
                #if prev_fname is not None and prev_fname != g_diff['__file']:
                #    print()
                prev_fname = g_diff['__file']
            write_out( '', out_f )

        write_out( f' Evaluated on {doc_count} documents. ', out_f )

# %%
evaluate_on_auto_morph_preprocess( bert_ner_tagger_phrases, test_data_dir, os.listdir(test_data_dir), output_fname )
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 252/252 [04:37<00:00,  1.10s/it]
# dict_keys(['missing', 'extra', 'wrong_label', 'wrong_boundaries + wrong_label', 'wrong_boundaries'])
#
# ======================================================================
# wrong_boundaries (115)
# ======================================================================
#  gold:  ...s, et tema Johan Kripsoniga "Kribsi" ja {"Mõtskribsi"} /LOC_ORG talud pooleks ostnud on; aga maad on we... | Tartu_V6nnu_Ahja_id17889_1885a
#  auto:  ...s, et tema Johan Kripsoniga "Kribsi" ja {"Mõtskribsi" talud} /LOC_ORG pooleks ostnud on; aga maad on weel poo...
#
#  gold:  ...k Kiwita kuha jägu on, sest tema on oma {(Laiba) kuha} /LOC_ORG ära ostnud nende rajadega, mis maamõõtj... | Harju_Jyri_Rae_id6623_1890a
#  auto:  ... Kiwita kuha jägu on, sest tema on oma ({Laiba} /LOC_ORG) kuha ära ostnud nende rajadega, mis ma...
#
#  gold:  ...rjutaja Wreimanniga õiges om saanud, ja {Adam} /PER Suurmann om sis selle massu tarwis tood... | V6ru_R2pina_Kahkva_id13937_1889a
#  auto:  ...rjutaja Wreimanniga õiges om saanud, ja {Adam Suurmann} /PER om sis selle massu tarwis toodud wilja ...
#
#  gold:  ...utty Jaani wargusse, mees sai Raetseppa {Adamist} /PER kätte saadut  jäi pudus 55 näila Zea Li... | Tartu_Kodavere_Pala_id19341_1846a
#  auto:  ...utty Jaani wargusse, mees sai Raetseppa {A} /PERdamist kätte saadut  jäi pudus 55 näila ...
#
#  gold:  ...\nTännasel pääwal sai {Adrako N 16 tallo} /LOC_ORG perremees Jakob Pern ja keik temma sugg... | Tartu_Torma_Avinurme_id17064_1870a
#  auto:  ...\nTännasel pääwal sai {Adrako} /LOC_ORG N 16 tallo perremees Jakob Pern ja keik...
#
#  gold:  ...tallo oksjoniwiisil wälja pakkutud.\n\nSe {Adrako N 16 tallo} /LOC_ORG mis 1 thaler 58 Grossi suured sai keige... | Tartu_Torma_Avinurme_id17064_1870a
#  auto:  ...tallo oksjoniwiisil wälja pakkutud.\n\nSe {Adrako} /LOC_ORG N 16 tallo mis 1 thaler 58 Grossi suure...
#
#  gold:  ...ärgmised lippingu kohtu poolt kinnitud.\n{Ahja} /LOC metsa sulaste Kontrakt.\nDawid Tenno oma... | Tartu_V6nnu_Ahja_id23436_1893a
#  auto:  ...ärgmised lippingu kohtu poolt kinnitud.\n{Ahja metsa} /LOC sulaste Kontrakt.\nDawid Tenno oma welle...
#
#  gold:  ...eli est Lawwakirrikust koddo tulnu nink {Ahja Moisakörtzi} /LOC_ORG man hulgal töiste Kirriko Rahwaga Obesi... | Tartu_V6nnu_Ahja_id11300_1872a
#  auto:  ...eli est Lawwakirrikust koddo tulnu nink {Ahja Moisakört} /LOC_ORGzi man hulgal töiste Kirriko Rahwaga Obe...
#
#  gold:  ...Hans.\n\nKohhus kutsus sedda Mihkle naest {Ann} /PER Kohtu ette, ning küsis: kas sinna wõid ... | P2rnu_Tori_Sindi_id19861_1835a
#  auto:  ...Hans.\n\nKohhus kutsus sedda Mihkle naest {Ann Kohtu} /PER ette, ning küsis: kas sinna wõid selle ...
#
#  gold:  ...rnst won Braschi ja Ahja walla talupoja {Dawid Peetri p. Lawasson} /PER wahel 6 Juunil maha on tehtud s.o. esim... | Tartu_V6nnu_Ahja_id4253_1907a
#  auto:  ...rnst won Braschi ja Ahja walla talupoja {Dawid Peetri p.} /PER {Lawasson} /PER wahel 6 Juunil maha on tehtud s.o. esim...
#
#  gold:  ...a omma poia est xxx bezahlt 3 Rbl\nN: 51 {Fadei Bogdanow Meruschew} /PER xxx\nGross. N: 11 Leonti Larionow Laschk... | Tartu_Kodavere_Alatskivi_id1744_1865a
#  auto:  ...a omma poia est xxx bezahlt 3 Rbl\nN: 51 {Fadei} /LOC_ORG {Bogdanow Meruschew} /PER xxx\nGross. N: 11 Leonti Larionow Laschk...
#
#  gold:  ...ma mees Jaan Laane) kaebuse asjas wasta {Fedor Wasiljewa} /PER {Kökkoral} /LOC, et see olla töiste wenelastega ühes ül... | Tartu_Kodavere_Alatskivi_id15625_1876a
#  auto:  ...ma mees Jaan Laane) kaebuse asjas wasta {Fedor Wasiljewa Kökkoral} /PER, et see olla töiste wenelastega ühes ül...
#
#  gold:  ...\n{Fökla Wasiljewna Poltowa} /PER omma mehhe Kusmaga kaebab Awdotja Andre... | Tartu_Kodavere_Alatskivi_id3374_1878a
#  auto:  ...\n{Fökla} /PER {Wasiljewna Poltowa} /PER omma mehhe Kusmaga kaebab Awdotja Andre...
#
#  gold:  ... Rbl\nN: 51 Fadei Bogdanow Meruschew xxx\n{Gross} /PER. N: 11 Leonti Larionow Laschkin xxx\nEt ... | Tartu_Kodavere_Alatskivi_id1744_1865a
#  auto:  ... Rbl\nN: 51 Fadei Bogdanow Meruschew xxx\n{Gross.} /PER N: 11 Leonti Larionow Laschkin xxx\nEt n...
#
#  gold:  ... walla liikmed Hans Jaani poeg Karro ja {Hans Hanso p. Johans} /PER walla kohtule palelikult tuntud ja palu... | J2rva_Tyri_Tyri-Alliku_id3270_1901a
#  auto:  ... walla liikmed Hans Jaani poeg Karro ja {Hans Hanso p.} /PER {Johans} /PER walla kohtule palelikult tuntud ja palu...
#
#  gold:  ...est tulnud ja pasle nahk olnud käes,kui {Hans P.} /PERtemaga rääkinud,pärast waidles seda taga... | Harju_Kose_Palvere_id23829_1887a
#  auto:  ...est tulnud ja pasle nahk olnud käes,kui {Hans P.temaga} /PER rääkinud,pärast waidles seda tagasi,et ...
#
#  gold:  ...\nJaan Saawa kaebas et temal {Hindr. Laari} /PER käest saada ja mis tema kätte nõuab:\n\n1... | Tartu_V6nnu_Ahja_id17409_1885a
#  auto:  ...\nJaan Saawa kaebas et temal {Hindr.} /PER {Laari} /PER käest saada ja mis tema kätte nõuab:\n\n1...
#
#  gold:  ...go wõtnud\n   200 rubl.\n  \n\n2\n   on tema {Hindr. Laari} /PER käest ühe hobuse ostnud mis tati tõpes ... | Tartu_V6nnu_Ahja_id17409_1885a
#  auto:  ...go wõtnud\n   200 rubl.\n  \n\n2\n   on tema {Hindr.} /PER {Laari} /PER käest ühe hobuse ostnud mis tati tõpes ...
#
#  gold:  ...ksma ja ei ole siis sellel enamb midagi {Hindr. Laari} /PER käest nõudmist.\n\nKohtomees: P. Hindriks... | Tartu_V6nnu_Ahja_id17409_1885a
#  auto:  ...ksma ja ei ole siis sellel enamb midagi {Hindr.} /PER {Laari} /PER käest nõudmist.\n\nKohtomees: P. Hindriks...
#
#  gold:  ...a münud ning se olli Tonnis Noulik waip {Hindrik} /PER aias sedda walleks et temma polle waipa... | Saare_Kihelkonna_Kotlandi_id15250_1860a
#  auto:  ...a münud ning se olli Tonnis Noulik waip {Hindrik aias} /PER sedda walleks et temma polle waipa peäl...
#
#  gold:  ...olli ka padi seltsis ning se purri olli {Hindrika} /LOC_ORG perre mihhe ja hindrik on se purjo selt... | Saare_Kihelkonna_Kotlandi_id15250_1860a
#  auto:  ...olli ka padi seltsis ning se purri olli {Hindrika perre} /LOC_ORG mihhe ja hindrik on se purjo seltsis se...
#
#  gold:  ...dsahüs, ent mina ei ole mitte nännü kui {Hint Raat} /PER{Silingut} /PER pesnü om.\n\nTunnistaja Jakob Sik Lutteri... | V6ru_Vastseliina_Misso_id5473_1885a
#  auto:  ...dsahüs, ent mina ei ole mitte nännü kui {Hint RaatSilingut} /PER pesnü om.\n\nTunnistaja Jakob Sik Lutteri...
#
#  gold:  ...n ostnud Pawel Alango Mihkli poja käest {Hütti wabat koha} /LOC_ORG peal olewad majad, mis eest Alango maks... | L22ne_Reigi_K6rgessaare_id23392_1896a
#  auto:  ...n ostnud Pawel Alango Mihkli poja käest {Hütti wabat} /LOC_ORG koha peal olewad majad, mis eest Alango...
#
#  gold:  ...ne rubla eest omale ostnud, nii et kõik {Hütti wabat koha} /LOC_ORG peal olewad majad minu omadus on ja kel... | L22ne_Reigi_K6rgessaare_id23392_1896a
#  auto:  ...ne rubla eest omale ostnud, nii et kõik {Hütti wabat} /LOC_ORG koha peal olewad majad minu omadus on j...
#
#  gold:  ...istan, et olen Peeter Eikile ära müinud {Hütti wabat koha} /LOC_ORG peal olewad majad nelja kümne rubla ees... | L22ne_Reigi_K6rgessaare_id23392_1896a
#  auto:  ...istan, et olen Peeter Eikile ära müinud {Hütti wabat} /LOC_ORG koha peal olewad majad nelja kümne rubl...
#
#  gold:  ...\nUemoisast\n\nAstus ette kaebaja {I. Köhler} /PER. Rentherra W. Güntheri nimmel ja kaebas... | Harju_Kose_Kose-Uuem6isa_id6138_1869a
#  auto:  ...\nUemoisast\n\nAstus ette kaebaja {I.} /PER Köhler. Rentherra W. Güntheri nimmel ja...
#
#  gold:  ...s sedda winud ei tea temma mitte öölda. {I. Köhler} /PER on temma laudilt agga heina prowi tonud... | Harju_Kose_Kose-Uuem6isa_id6138_1869a
#  auto:  ...edda winud ei tea temma mitte öölda. I. {Köhler} /PER on temma laudilt agga heina prowi tonud...
#
#  gold:  ... peakoht. K. Trauberg. Kõrwam. K. Luker {J. lipp} /PER.\n\nEtte tuli kaebaja Krõõt Lesser ja kae... | Harju_Keila_Harku_id14716_1869a
#  auto:  ... peakoht. K. Trauberg. Kõrwam. K. Luker {J.} /PER lipp.\n\nEtte tuli kaebaja Krõõt Lesser j...
#
#  gold:  ...kohtusse kaebanud, et temma surnud mees {Jaan} /PER {Liso Wahtkerile} /PER Laupalt 1 Tschet. odre Serrewerre magga... | J2rva_Tyri_S2revere_id14536_1886a
#  auto:  ...kohtusse kaebanud, et temma surnud mees {Jaan Liso Wahtkerile} /PER Laupalt 1 Tschet. odre Serrewerre magga...
#
#  gold:  ...inna wälja, nink lööp minnule käemehhes {Jaan Hussar.} /PER Jaan Hussar ei heida agga enne käemehhe... | V6ru_R6uge_Saaluse_id11774_1880a
#  auto:  ...inna wälja, nink lööp minnule käemehhes {Jaan Hussar} /PER. Jaan Hussar ei heida agga enne käemehh...
#
#  gold:  ...alla kohtu ette Nikolai walla talupojad {Jaan Jaani p. Jamul} /PER, ja Hans Jaani p. Jamul, kes mõlemad ko... | Harju_Kose_Palvere_id599_1909a
#  auto:  ...alla kohtu ette Nikolai walla talupojad {Jaan Jaani p.} /PER {Jamul} /PER, ja Hans Jaani p. Jamul, kes mõlemad ko...
#
#  gold:  ...kirjutatud tema, Saanbergi, palwe peale {Jaan Jaani p. Rebaselt} /PER.\n\nEesistuja M. Reiman /allkiri/\n\nLiikme... | J2rva_Tyri_V22tsa_id21785_1909a
#  auto:  ...kirjutatud tema, Saanbergi, palwe peale {Jaan Jaani p.} /PER {Rebaselt} /PER.\n\nEesistuja M. Reiman /allkiri/\n\nLiikme...
#
#  gold:  ...ei oska, kirjutas tema palwe peale alla {Jaan Jani boek Rebane} /PER /allkiri/\n\nSee testament on mahakirjuta... | J2rva_Tyri_V22tsa_id21785_1909a
#  auto:  ...ei oska, kirjutas tema palwe peale alla {Jaan Jani} /PER bo{ek Rebane} /PER /allkiri/\n\nSee testament on mahakirjuta...
#
#  gold:  ...                       Kirjutaja        {Jaan, Kukk} /PER,\n\n\n... | Tartu_Kodavere_Pala_id18167_1862a
#  auto:  ...                       Kirjutaja        {Jaan, Kukk,} /PER\n\n\n...
#
#  gold:  ...wast 1912 a., oma kahe pojale Jürile ja {Jaanile} /PER {Martinitele} /PER kahe peale kokku pooleks, järgmistel ti... | Harju_Juuru_Kaiu_id925_1911a
#  auto:  ...wast 1912 a., oma kahe pojale Jürile ja {Jaanile Martinitele} /PER kahe peale kokku pooleks, järgmistel ti...
#
#  gold:  ...Siis kostis temma 1 olnudpilleti soldat {Jakob nimmi} /PER Maddise Kihhelkonnast 2. olnud mamees n... | Harju_Keila_Harku_id14723_1869a
#  auto:  ...Siis kostis temma 1 olnudpilleti soldat {Jakob} /PER nimmi Maddise Kihhelkonnast 2. olnud ma...
#
#  gold:  ...ekõige 130 rubla\n\nEls Mutso oma kurator {Joh. Jänesega} /PER ütles nõudmise õige olewat.\n\nMõiste: Jo... | Tartu_V6nnu_Ahja_id17819_1885a
#  auto:  ...ekõige 130 rubla\n\nEls Mutso oma kurator {Joh.} /PER {Jänesega} /PER ütles nõudmise õige olewat.\n\nMõiste: Jo...
#
#  gold:  ...\nAne Rebane, {Joh. Matsoni} /PER man seistes, kaibas, et sõsare poeg Jaa... | Tartu_V6nnu_Ahja_id16466_1884a
#  auto:  ...\nAne Rebane, {Joh.} /PER {Matsoni} /PER man seistes, kaibas, et sõsare poeg Jaa...
#
#  gold:  ...lda selle peremehe mano, kedas tema isa {Joh. Puhkim} /PER temale on kaubelnud.\n\nPeter Kripson XXX... | Tartu_V6nnu_Ahja_id14014_1882a
#  auto:  ...lda selle peremehe mano, kedas tema isa {Joh.} /PER {Puhkim} /PER temale on kaubelnud.\n\nPeter Kripson XXX...
#
#  gold:  ...d.\n\nMõiste: D. Margk wõib kahjutasumist {Joh. Wariku} /PER käest nõuda, sest et Warik tõeks teha e... | Tartu_V6nnu_Ahja_id17662_1885a
#  auto:  ...d.\n\nMõiste: D. Margk wõib kahjutasumist {Joh.} /PER {Wariku} /PER käest nõuda, sest et Warik tõeks teha e...
#
#  gold:  ...kiri/\n\nKirjutaja Pommer /allkiri/\n\nMina {Juhannes Jüri p. Erenwert} /PER 1921 a. aprilli kuu 27 päewal annan oma... | J2rva_Tyri_V22tsa_id22576_1916a
#  auto:  ...kiri/\n\nKirjutaja Pommer /allkiri/\n\nMina {Juhannes Jüri p.} /PER Er{en} /PERwert 1921 a. aprilli kuu 27 päewal annan...
#
#  gold:  ...ibaja: Kähri Preester Nikolski\nKaibatu: {Jukku Körtsi} /LOC_ORG mees Jaan Luhha\nKörtsimees Jaan Luhha o... | V6ru_P6lva_K2hri_id21539_1850a
#  auto:  ...ibaja: Kähri Preester Nikolski\nKaibatu: {Jukku K} /PER{örtsi} /LOC_ORG mees Jaan Luhha\nKörtsimees Jaan Luhha o...
#
#  gold:  ... olli tedda tagga aianud, ja olli tedda {Jõelehtme külla kõrtsust} /LOC_ORG kätte sanud, ja siis olli sest rahhast ... | Harju_J6el2htme_J6el2htme_id7364_1868a
#  auto:  ... olli tedda tagga aianud, ja olli tedda {Jõelehtme külla} /LOC_ORG kõr{tsust} /LOC_ORG kätte sanud, ja siis olli sest rahhast ...
#
#  gold:  ... andiks, et temma wölsnu olli, et temma {Jürri} /PER Karja mant Ärraminnekid Rentnik Johanso... | Tartu_V6nnu_Ahja_id11395_1872a
#  auto:  ... andiks, et temma wölsnu olli, et temma {Jürri Karja} /PER mant Ärraminnekid Rentnik Johansonile o...
#
#  gold:  ... rbl 50 kop nõndasama 4 nädali aea sees {Kahkwa} /LOC_ORG waeste laadiku haas wälja maksma.\n\nSee ... | V6ru_R2pina_Kahkva_id8832_1888a
#  auto:  ... rbl 50 kop nõndasama 4 nädali aea sees {Ka} /LOC{hkwa} /LOC_ORG waeste laadiku haas wälja maksma.\n\nSee ...
#
#  gold:  ...bre, et temma om Werriorra naisi leidnu {Kahkwa raodu} /LOC hainu põimast. Neid om ollu 2 naist ja ... | V6ru_R2pina_Kahkva_id21295_1867a
#  auto:  ...bre, et temma om Werriorra naisi leidnu {Kahkwa} /LOC raodu hainu põimast. Neid om ollu 2 nai...
#
#  gold:  ...eest 1 Rubla, sai moistetud.\n\n4. Kangro {Karel} /PER {Säritsast} /LOC 1. Kuusk 8 tolli paks 40 kkop. ja wie h... | Tartu_Kodavere_Ranna_id14148_1855a
#  auto:  ...eest 1 Rubla, sai moistetud.\n\n4. Kangro {Karel Säritsast} /PER 1. Kuusk 8 tolli paks 40 kkop. ja wie h...
#
#  gold:  ...Pulst edaspidi enam Juri Klaasseni poeg {Karl Ferdinand Klaasseni} /PER omale lapse asemele wõtta ehk pidada ei... | P2rnu_Tori_Sindi_id3457_1884a
#  auto:  ...Pulst edaspidi enam Juri Klaasseni poeg {Karl} /PER {Ferdinand Klaasseni} /PER omale lapse asemele wõtta ehk pidada ei...
#
#  gold:  ...st, et Soldat Jakob Adamson, kea praego {Kastren} /LOC ellab, om minnewa ajasta temmaga Mudako... | Tartu_V6nnu_Ahja_id12794_1875a
#  auto:  ...st, et Soldat Jakob Adamson, kea praego {Kast} /LOC_ORG{ren} /LOC ellab, om minnewa ajasta temmaga Mudako...
#
#  gold:  ... Ballberg läbi oma sulaste peale nimelt {Kiistas Wiikmann} /PER soldat Juhan Sais ja soldat Tõnnis Peek... | L22ne_Kullamaa_K22nda_id22411_1882a
#  auto:  ...g läbi oma sulaste peale nimelt Kiistas {Wiikmann} /PER soldat Juhan Sais ja soldat Tõnnis Peek...
#
#  gold:  ...oisa rent Herra Vogt on ka öölnud: "Kui {Kiiwita kohta} /LOC_ORG oleks mõisa kätte saanud, kül mina siis... | Harju_Jyri_Rae_id6623_1890a
#  auto:  ...oisa rent Herra Vogt on ka öölnud: "Kui {Kiiwita} /LOC_ORG kohta oleks mõisa kätte saanud, kül min...
#
#  gold:  ... ja kaebas, et üks tük õue aja maad mis {Kiiwita kuha} /LOC_ORG jagu on ja N 4 all peab olema kaartis j... | Harju_Jyri_Rae_id6623_1890a
#  auto:  ... ja kaebas, et üks tük õue aja maad mis {Kiiwita} /LOC_ORG kuha jagu on ja N 4 all peab olema kaar...
#
#  gold:  ...is, ega tema kaartis, waid se maatük on {Kiiwita kuha} /LOC_ORG numri all, sest Kiiwita kuha õuemaad on... | Harju_Jyri_Rae_id6623_1890a
#  auto:  ...is, ega tema kaartis, waid se maatük on {Kiiwita} /LOC_ORG kuha numri all, sest Kiiwita kuha õuema...
#
#  gold:  ... maatük on Kiiwita kuha numri all, sest {Kiiwita kuha} /LOC_ORG õuemaad on kaartis N 4 all. Ja seda maa... | Harju_Jyri_Rae_id6623_1890a
#  auto:  ... maatük on Kiiwita kuha numri all, sest {Kiiwita} /LOC_ORG kuha õuemaad on kaartis N 4 all. Ja sed...
#
#  gold:  ...le Laiba jägu, se maa tük on N 4 all ja {Kiiwita maa} /LOC_ORG on ka N 4 all. \n\nSelle peale sai ette k... | Harju_Jyri_Rae_id6623_1890a
#  auto:  ...le Laiba jägu, se maa tük on N 4 all ja {Kiiwita} /LOC_ORG maa on ka N 4 all. \n\nSelle peale sai et...
#
#  gold:  ...raja wastu weski maad ei tule, et se on {Kiiwita maa} /LOC_ORG mis wastu weski maad on lauda taga üle ... | Harju_Jyri_Rae_id6623_1890a
#  auto:  ...raja wastu weski maad ei tule, et se on {Kiiwita} /LOC_ORG maa mis wastu weski maad on lauda taga ...
#
#  gold:  ... Siimberg. \n\nKohtu ette tuli Rae wallast{Kiiwita talu kuha} /LOC_ORG rentnik Jaan Hio ja kaebas, et üks tük ... | Harju_Jyri_Rae_id6623_1890a
#  auto:  ... Siimberg. \n\nKohtu ette tuli Rae wallast{Kiiwita talu} /LOC_ORG kuha rentnik Jaan Hio ja kaebas, et üks...
#
#  gold:  ...,et wastamise kaebavad,mis Wõrgo loomad {Kingsepa} /PER heinas ja orraksel olnud ja Kingsepa lo... | Harju_Kose_Palvere_id17520_1882a
#  auto:  ...,et wastamise kaebavad,mis Wõrgo loomad {King} /LOC_ORG{sepa} /PER heinas ja orraksel olnud ja Kingsepa lo...
#
#  gold:  ...a Fedolajewna omma mehhe est xxx\nN: 19. {Kirila Trofimow Usanow} /PER xxx\nWeikse-Kolkja\nN: 3 Awdotja Awsejewn... | Tartu_Kodavere_Alatskivi_id1744_1865a
#  auto:  ...a Fedolajewna omma mehhe est xxx\nN: 19. {Kirila} /LOC_ORG {Trofimow Usanow} /PER xxx\nWeikse-Kolkja\nN: 3 Awdotja Awsejewn...
#
#  gold:  ...t tema seda mitte ei tea, et se maa tük {Kiwita kuha} /LOC_ORG jägu on, sest tema on oma (Laiba) kuha ... | Harju_Jyri_Rae_id6623_1890a
#  auto:  ...t tema seda mitte ei tea, et se maa tük {Kiw} /LOC_ORG{ita} /LOC kuha jägu on, sest tema on oma (Laiba) ...
#
#  gold:  ...ise kulu pääle ühel maa mõõtjal ostetud {Kripsi maad} /LOC_ORG taadrete järele takseeritud pooleks mõõ... | Tartu_V6nnu_Ahja_id17889_1885a
#  auto:  ...ise kulu pääle ühel maa mõõtjal ostetud {Kri} /PER{psi} /LOC_ORG maad taadrete järele takseeritud poolek...
#
#  gold:  ... ning säelt otsust sada, Kaibatawa Sato {Kristjan} /PER{Kärla wallast} /LOC_ORG temma on Tõnnise kapss aja häddala ning... | Saare_K2rla_K2rla_id5732_1827a
#  auto:  ... ning säelt otsust sada, Kaibatawa Sato {KristjanKär} /PER{la wallast} /LOC_ORG temma on Tõnnise kapss aja häddala ning...
#
#  gold:  ...ihkel Sudar Terefer 12 rubla 86 kop. ja {Kristjan Meisin} /PER {Terefer} /LOC 4 rubl. Peter Kontin Terefer 2 rubl 60 ... | Viru_Iisaku_Iisaku_id2927_1885a
#  auto:  ...ihkel Sudar Terefer 12 rubla 86 kop. ja {Kristjan Meisin Terefer} /PER 4 rubl. Peter Kontin Terefer 2 rubl 60 ...
#
#  gold:  ..., mustakas tempel, nisamma kui teistel.\n{Kusta Nuggin} /PER{Kokkoralt} /LOC tunnistab, et temma polle Karel Kusikug... | Tartu_Kodavere_Alatskivi_id2193_1878a
#  auto:  ..., mustakas tempel, nisamma kui teistel.\n{Kusta NugginKok} /PER{koralt} /LOC tunnistab, et temma polle Karel Kusikug...
#
#  gold:  ...II] Ausa {Kärla mõisa mõisawallitsusse} /ORG kässo järrele, wõttis koggokonna kohhus... | Saare_K2rla_K2rla_id5732_1827a
#  auto:  ...II] {Ausa Kärla mõisa mõisawallitsusse} /ORG kässo järrele, wõttis koggokonna kohhus...
#
#  gold:  ...ingk, et temma saap need Moisamaad, mis {Kütsaare} /LOC päle om, kos wahhel nüd Pier om tettu K... | Tartu_R6ngu_Aakre_id12415_1827a
#  auto:  ...ingk, et temma saap need Moisamaad, mis {Kü} /PER{tsaare} /LOC_ORG päle om, kos wahhel nüd Pier om tettu K...
#
#  gold:  ...a aijanud ja ütlenud need ellajad ollid {Kütta Mihkli} /PER ommad.\n\nMõistus.\n\nEt need karjapoisid M... | Tartu_Torma_Avinurme_id23098_1872a
#  auto:  ...a aijanud ja ütlenud need ellajad ollid {Kütta} /LOC_ORG {Mihkli} /PER ommad.\n\nMõistus.\n\nEt need karjapoisid M...
#
#  gold:  ...danud ütlema, et se maatük ei ole mitte {Laiba kuha} /LOC_ORG numris, ega tema kaartis, waid se maatü... | Harju_Jyri_Rae_id6623_1890a
#  auto:  ...danud ütlema, et se maatük ei ole mitte {Laiba} /LOC_ORG kuha numris, ega tema kaartis, waid se ...
#
#  gold:  ...jadega, mis maamõõtja on 1879mal aastal {Laiba kuhale} /LOC_ORG pannud ja 11 aastad on tema seda maatük... | Harju_Jyri_Rae_id6623_1890a
#  auto:  ...jadega, mis maamõõtja on 1879mal aastal {Laiba} /LOC_ORG kuhale pannud ja 11 aastad on tema seda...
#
#  gold:  ...t on temale jäänud 34 tündrid kartuflid {Leppa kuha} /LOC_ORG peale. \n\nSeda kinnitab Leppa perenaine ... | Harju_Jyri_Rae_id9404_1890a
#  auto:  ...t on temale jäänud 34 tündrid kartuflid {Leppa} /LOC_ORG kuha peale. \n\nSeda kinnitab Leppa peren...
#
#  gold:  ...ol saab Jürile, aga teine pool Jaanile; {Lihu maa heina maa} /LOC saab pikuti pooleks teine pool teisele,... | Harju_Juuru_Kaiu_id925_1911a
#  auto:  ...ol saab Jürile, aga teine pool Jaanile; {Li} /LOChu maa heina maa saab pikuti pooleks tei...
#
#  gold:  ...o Karli t. Koost poolt ühest küljest ja {Liisa Johani t. Nõukasi} /PER wahel teisest küljest, kelledel mõlemat... | Saare_Kaarma_Loona_id18800_1917a
#  auto:  ...o Karli t. Koost poolt ühest küljest ja {Liisa Johani t.} /PER {Nõukasi} /PER wahel teisest küljest, kelledel mõlemat...
#
#  gold:  ...sisse kirjutud ja tehtud naesterahvaste {Liiso Karli t. Koost} /PER poolt ühest küljest ja Liisa Johani t. ... | Saare_Kaarma_Loona_id18800_1917a
#  auto:  ...sisse kirjutud ja tehtud naesterahvaste {Liiso Karli t.} /PER Koost poolt ühest küljest ja Liisa Joha...
#
#  gold:  ...ee kohto  otsus sai nende kohtokäiatele {Liiwl. Talu. Säd} /MISC  §773 kuulutatud. Jaak Kalt ei olnud se... | V6ru_P6lva_Kiuma_id6097_1880a
#  auto:  ...ee kohto  otsus sai nende kohtokäiatele {Liiwl.} /MISC Talu. {Säd} /MISC  §773 kuulutatud. Jaak Kalt ei olnud se...
#
#  gold:  ... ühemastilise laewa "Georgist" möisniku {Magnus v. Freymann'ile} /PER ühesaja rubla eest ära müünud, mis summ... | L22ne_Emmaste_Emmaste_id15328_1895a
#  auto:  ... ühemastilise laewa "Georgist" möisniku {Magnus v.} /PER {Freymann'ile} /PER ühesaja rubla eest ära müünud, mis summ...
#
#  gold:  ...ns Karro käest oma wenna Johannes ja õe {Maria Elisabeth Johansile} /PER (kumbagile) nüüd mehe järele Idla, kumb... | J2rva_Tyri_Tyri-Alliku_id3270_1901a
#  auto:  ...ns Karro käest oma wenna Johannes ja õe {Maria} /PER {Elisabeth Johansile} /PER (kumbagile) nüüd mehe järele Idla, kumb...
#
#  gold:  ...Silla Otsa Samo man, WastseKusten olnud {Marri} /PER Talwen teeniman, wöib olla, et säl temm... | Tartu_V6nnu_Ahja_id12890_1875a
#  auto:  ...Silla Otsa Samo man, WastseKusten olnud {Marri Talwen} /PER teeniman, wöib olla, et säl temma hinda...
#
#  gold:  ...ise Kihhelkonnast 2. olnud mamees nimmi {Mart} /PER- ? ja 3. pidanud Risiperre mees ollema ... | Harju_Keila_Harku_id14723_1869a
#  auto:  ...ise Kihhelkonnast 2. olnud mamees nimmi {Mart- ?} /PER ja 3. pidanud Risiperre mees ollema ja ...
#
#  gold:  ...omann.\n\nPea kohtomehheks sai Taawet Kuu {Martna w} /LOC_ORG.\n\nKohto kõrwameesteks : Jaan Selart Put... | L22ne_Martna_Martna_id14608_1869a
#  auto:  ...omann.\n\nPea kohtomehheks sai Taawet Kuu {Martna w.} /LOC_ORG\n\nKohto kõrwameesteks : Jaan Selart Putk...
#
#  gold:  ...d ei olle. Ka woin ma seda tunistada et {Matsi} /LOC_ORG{Jaani Madisoni} /PER loomad heinamaale aetakse sest ma olen ... | L22ne_Ridala_Sinalepa_id24367_1884a
#  auto:  ...d ei olle. Ka woin ma seda tunistada et {MatsiJaani} /LOC_ORG {Madisoni} /PER loomad heinamaale aetakse sest ma olen ...
#
#  gold:  ...ni see wõlg tasutud on. Selle eest peab {Mauer Kredemanni} /PER ja tema naist surmani toitma ja katma j... | J2rva_Tyri_V22tsa_id20183_1899a
#  auto:  ...ni see wõlg tasutud on. Selle eest peab {Mauer} /PER {Kredemanni} /PER ja tema naist surmani toitma ja katma j...
#
#  gold:  ...sili maha läinud. Selle peale ola tema /{Märt Leppiku} /PER mehed kisa teinud ja söimama hakkanud, ... | Viljandi_Tarvastu_Tarvastu_id4042_1875a
#  auto:  ...sili maha läinud. Selle peale ola tema /{M} /PER{ärt Leppiku} /PER mehed kisa teinud ja söimama hakkanud, ...
#
#  gold:  ...kata. Robensee andis tunnistajaks ülese:{Märt Wain} /PER ja Andres Rooson ja töie ka see kaerato... | Viljandi_Tarvastu_Tarvastu_id4042_1875a
#  auto:  ...kata. Robensee andis tunnistajaks ülese:{M} /PER{ärt Wain} /PER ja Andres Rooson ja töie ka see kaerato...
#
#  gold:  ...bl. Peter Kontin Terefer 2 rubl 60 kop. {Nigulas Sabolotsi} /PER {Iisakust} /LOC 12 rubl. 44 kop. on wölgu. Kohtu küsimi... | Viru_Iisaku_Iisaku_id2927_1885a
#  auto:  ...bl. Peter Kontin Terefer 2 rubl 60 kop. {Nigulas} /PER {Sabolotsi Iisakust} /LOC 12 rubl. 44 kop. on wölgu. Kohtu küsimi...
#
#  gold:  ...uar 1880 sub N 180 sai tänna sel päewal {Nikolai Maksimow Jewa} /PER kohtu ette kutsutud, ja temmale siitpoo... | Tartu_Kodavere_Alatskivi_id10084_1880a
#  auto:  ...uar 1880 sub N 180 sai tänna sel päewal {Nikolai Maksimow} /PER {Jewa} /ORG kohtu ette kutsutud, ja temmale siitpoo...
#
#  gold:  ...na, Peeter Eik Andrule poeg olen ostnud {Pawel Alango} /PER Mihkli poja käest Hütti wabat koha peal... | L22ne_Reigi_K6rgessaare_id23392_1896a
#  auto:  ...na, Peeter Eik Andrule poeg olen ostnud {Pawel} /PER {Alango} /PER Mihkli poja käest Hütti wabat koha peal...
#
#  gold:  ...tulnu, neid Rükki käest andma, et Wösmi {Pedo} /PER Korman üts kott om puudus olnu ja temma... | Tartu_V6nnu_Ahja_id21838_1868a
#  auto:  ...tulnu, neid Rükki käest andma, et Wösmi {Pedo Korman} /PER üts kott om puudus olnu ja temma essi n...
#
#  gold:  ...t Karel Niidik Kewwade 1873 selle poole {Petri Tallo asseme} /LOC_ORG peab ärraandma sellepärrast et Kusta Nu... | Tartu_Kodavere_Pala_id23317_1872a
#  auto:  ...t Karel Niidik Kewwade 1873 selle poole {Petri Tallo} /LOC_ORG asseme peab ärraandma sellepärrast et K...
#
#  gold:  ...tuli kaebaja Krõõt Lesser ja kaebas, et {Platsi} /LOC_ORG {Rostawi} /PER poeg Kustaw Lihwerts on temma tütre ärr... | Harju_Keila_Harku_id14716_1869a
#  auto:  ...tuli kaebaja Krõõt Lesser ja kaebas, et {Platsi Rostawi} /PER poeg Kustaw Lihwerts on temma tütre ärr...
#
#  gold:  ...ista.\n\nAlexander Feodorow Panikowitsast {Poläni küläst} /LOC_ORG ütles et se om kül õige et mina ole And... | V6ru_Vastseliina_Misso_id10553_1886a
#  auto:  ...ista.\n\nAlexander Feodorow Panikowitsast {Poläni} /LOC_ORG küläst ütles et se om kül õige et mina ...
#
#  gold:  ..., muud tema ei tea kosta. \n\nSelle peale {Rae} /LOC_ORG walla Tallitaja Jüri Remmel tunnistas: ... | Harju_Jyri_Rae_id6623_1890a
#  auto:  ..., muud tema ei tea kosta. \n\nSelle peale {Rae walla} /LOC_ORG Tallitaja Jüri Remmel tunnistas: Et Was...
#
#  gold:  ...ikust on tulnud,siin on Leiste peremees {Rein} /PER õuewärawas tema käest küsinud:kuidas se... | Harju_Kose_Palvere_id23829_1887a
#  auto:  ...ikust on tulnud,siin on Leiste peremees {Rein õuewärawas} /PER tema käest küsinud:kuidas see õunawargu...
#
#  gold:  ...e iselikult tuntud  Kirna walla liikmed {Rein Hansu p. Kredemann} /PER ja Mart Mardi p. Mauer ja  palusid kohu... | J2rva_Tyri_V22tsa_id20183_1899a
#  auto:  ...e iselikult tuntud  Kirna walla liikmed {Rein Hansu p.} /PER {Kredemann} /PER ja Mart Mardi p. Mauer ja  palusid kohu...
#
#  gold:  ...Mansu tunistas et see tõsi küll olla,et {Rein L.} /PER{Jaani} /PER lubanud peksta,mitte aga wana wiha,waid... | Harju_Kose_Palvere_id23829_1887a
#  auto:  ...Mansu tunistas et see tõsi küll olla,et {Rein L.Jaani} /PER lubanud peksta,mitte aga wana wiha,waid...
#
#  gold:  ... peäwa tööde rahha sepärrast maksta, et {Reino} /PER Ellajad on kaks suid temma krundi peal ... | J2rva_Tyri_Kirna_id23074_1871a
#  auto:  ... peäwa tööde rahha sepärrast maksta, et {Reino Ellajad} /PER on kaks suid temma krundi peal karjas k...
#
#  gold:  ... soowib Serewere mõisa pärisherra Baron {Schillingi} /PER läbi oma "Sepa" päriskoha Eestimaa Kred... | J2rva_Tyri_S2revere_id15372_1888a
#  auto:  ...t tema soowib Serewere mõisa pärisherra {Baron Schillingi} /PER läbi oma "Sepa" päriskoha Eestimaa Kred...
#
#  gold:  ... Liso Wahtkerile Laupalt 1 Tschet. odre {Serrewerre maggaski aidast} /LOC laenanud, mis Liso Wahtker seia sadik w... | J2rva_Tyri_S2revere_id14536_1886a
#  auto:  ... Liso Wahtkerile Laupalt 1 Tschet. odre {Serrewerre mag} /LOCgaski aidast laenanud, mis Liso Wahtker ...
#
#  gold:  ...Tännatsel päwal on all nimmetedu {Suure- ja Weikse-Kolkja} /LOC rendipiddajille, neide siin tehtu ja al... | Tartu_Kodavere_Alatskivi_id1744_1865a
#  auto:  ...Tännatsel päwal on all nimmetedu {Suure} /LOC_ORG{-} /ORG ja {We} /LOC_ORG{ikse-Kolkja} /LOC rendipiddajille, neide siin tehtu ja al...
#
#  gold:  ...id ette ja pallusid et Kohhus nenda kui {Tallorahwa seädusse ramato} /MISC §1056 õppetab, nende wahhel pärrimisse ... | Tartu_Kodavere_Alatskivi_id13251_1856a
#  auto:  ...id ette ja pallusid et Kohhus nenda kui {Tallorahwa seädusse} /MISC ramato §1056 õppetab, nende wahhel pärr...
#
#  gold:  ...ni ei ole tasutud.\n\nSee otsus sai neile {Talurahwa Sääd} /MISC: raames §§ 772 ja 773 põhja järele ette... | Tartu_Kodavere_Alatskivi_id15625_1876a
#  auto:  ...ni ei ole tasutud.\n\nSee otsus sai neile {Talurahwa Sääd:} /MISC raames §§ 772 ja 773 põhja järele ettek...
#
#  gold:  ...kroon, Tõnu Juhkum, Juhan Rüütel, Wanna {Tihanohv} /PER, ja Ludwi Rosikohw saawad kohtu poolt k... | Harju_Kuusalu_K6nnu_id14450_1880a
#  auto:  ... Heinakroon, Tõnu Juhkum, Juhan Rüütel, {Wanna Tihanohv} /PER, ja Ludwi Rosikohw saawad kohtu poolt k...
#
#  gold:  ...gusolt toond ja ärra münud ning se olli {Tonnis Noulik} /PER waip Hindrik aias sedda walleks et temm... | Saare_Kihelkonna_Kotlandi_id15250_1860a
#  auto:  ...gusolt toond ja ärra münud ning se olli {Tonnis} /LOC {Noulik} /PER waip Hindrik aias sedda walleks et temm...
#
#  gold:  ...u koosolekule kohtule isiklikult tuntud {Tõnis Tõnise p. Handschmidt} /PER ja Jaak Mihkle p. Tohterberg, mõlemad K... | J2rva_Tyri_V22tsa_id20815_1905a
#  auto:  ...u koosolekule kohtule isiklikult tuntud {Tõnis Tõnise p.} /PER {Handschmidt} /PER ja Jaak Mihkle p. Tohterberg, mõlemad K...
#
#  gold:  ...t ja andis küsimiseel tunnistuseks: Kui {Tõrwa} /LOC_ORG wana peremees Jaan Bauer haige olnud, k... | Viljandi_K6pu_Suure-K6pu_id6257_1884a
#  auto:  ...t ja andis küsimiseel tunnistuseks: Kui {Tõrwa wana} /LOC_ORG peremees Jaan Bauer haige olnud, kutsun...
#
#  gold:  ...{Ue Põltsama moisas} /LOC_ORG sell 4. August 1852\nKohtu polest olli k... | Viljandi_P6ltsamaa_Uue-P6ltsamaa_id2678_1852a
#  auto:  ...{Ue} /LOC {Põltsama moisas} /LOC_ORG sell 4. August 1852\nKohtu polest olli k...
#
#  gold:  ...ma pool olnud, ent Silla Otsa Samo man, {WastseKusten} /LOC olnud Marri Talwen teeniman, wöib olla,... | Tartu_V6nnu_Ahja_id12890_1875a
#  auto:  ...ma pool olnud, ent Silla Otsa Samo man, {WastseK} /LOC_ORG{usten} /PER olnud Marri Talwen teeniman, wöib olla,...
#
#  gold:  ...male 38 Rubl. 40 kop. ärra, ketti temma {Weenemaale} /LOC Maa Ostmissest weel peab saama.\nKüttipe... | Tartu_V6nnu_Ahja_id9067_1871a
#  auto:  ...le 38 Rubl. 40 kop. ärra, ketti temma We{ene} /LOCmaale Maa Ostmissest weel peab saama.\nKü...
#
#  gold:  ...ud: Reede peale lõune olla Paap Warrusk {Weiko Weerksu} /LOC kõrtsist mööda läinud ja olnu musta kot... | V6ru_R2pina_Kahkva_id8832_1888a
#  auto:  ...ud: Reede peale lõune olla Paap Warrusk {Weiko} /LOC {Weerksu kõrtsist} /LOC_ORG mööda läinud ja olnu musta kottiga mida...
#
#  gold:  ...arwa järge olnu om kellega Paap Warrusk {Weiko Weerksu} /LOC kõrtsist mööda om läinud, kus see waras... | V6ru_R2pina_Kahkva_id8832_1888a
#  auto:  ...arwa järge olnu om kellega Paap Warrusk {Weiko} /LOC_ORG {Weerksu kõrtsist} /LOC_ORG mööda om läinud, kus see warastud kask ...
#
#  gold:  ...p Adoson XXX \n\nPeter Akkert XXX ​ ​​​​​​{Widrik Harkmann} /PER XXX\n\n\n... | Tartu_V6nnu_Ahja_id22125_1868a
#  auto:  ...X Josep Adoson XXX \n\nPeter Akkert XXX ​ {​​​​​​Widrik Harkmann} /PER XXX\n\n\n...
#
#  gold:  ...ina olin 20 1/2 päewa möldri toa juures {Willem Kiriku} /PER all tööl ja kauplesin 50 kopikat päew 6... | J2rva_Ambla_Ambla_id7566_1888a
#  auto:  ...ina olin 20 1/2 päewa möldri toa juures {Willem Kiriku all} /PER tööl ja kauplesin 50 kopikat päew 6 rub...
#
#  gold:  ...mehhed: Hans Pent, Jaan Pernstein\n\n39.  {Willita} /LOC {Toma} /LOC_ORG perrenaene Mai Tagobert olli kohtusse k... | J2rva_Tyri_S2revere_id14536_1886a
#  auto:  ...mehhed: Hans Pent, Jaan Pernstein\n\n39.  {Willita Toma} /LOC_ORG perrenaene Mai Tagobert olli kohtusse k...
#
#  gold:  ...han Lippur annab Jaan Susile Lauguri ja {Wõsala} /LOC_ORG talud rendi peale, sedawiisi kui tema e... | Viljandi_P6ltsamaa_Adavere_id17466_1894a
#  auto:  ...han Lippur annab Jaan Susile Lauguri ja {Wõsala talud} /LOC_ORG rendi peale, sedawiisi kui tema enne lä...
#
#  gold:  ...Limberg andsin 23 Aprillist 1912 a. oma {rendi talu "Juhani"} /LOC_ORG Kaiu wallas, oma poja Hans Limbergile k... | Harju_Juuru_Kaiu_id961_1912a
#  auto:  ...g andsin 23 Aprillist 1912 a. oma rendi {talu} /LOC_ORG {"Juhani"} /LOC_ORG Kaiu wallas, oma poja Hans Limbergile k...
#
#  gold:  ...les wõtta.\n\nMina Pearn Martin annan oma {rendi talu - Pendijaagu} /LOC_ORG, mis on Kaiu wallas Kaswandu külas - pi... | Harju_Juuru_Kaiu_id925_1911a
#  auto:  ...les wõtta.\n\nMina Pearn Martin annan oma {rendi talu} /LOC_ORG - {Pendijaagu} /LOC_ORG, mis on Kaiu wallas Kaswandu külas - pi...
#
#
# ======================================================================
# extra (66)
# ======================================================================
#  gold:  ...ona wallas, Wantri külas Wälja Liiso N139" wabaniku platsi peal, kõige selle plat... | Saare_Kaarma_Loona_id18800_1917a
#  auto:  ...ona wallas, Wantri külas Wälja Liiso N13{9} /PER" wabaniku platsi peal, kõige selle plat...
#
#  gold:  ...nud ka luggu sest hobbusel olnud jallas Breid ja temma annud 40 rubla peale agga annu... | Viljandi_P6ltsamaa_Pajusi_id4984_1872a
#  auto:  ...nud ka luggu sest hobbusel olnud jallas {Breid} /PER ja temma annud 40 rubla peale agga annu...
#
#  gold:  ...Rahha 2 Rub. 6 kop. ja weel Koolmeistri Eina rahha 12 1/2 ja maggasi wilja wõlga ruk... | Tartu_Kodavere_Pala_id17236_1857a
#  auto:  ...Rahha 2 Rub. 6 kop. ja weel Koolmeistri {Eina} /PER rahha 12 1/2 ja maggasi wilja wõlga ruk...
#
#  gold:  ...eme\n  \n\n2 wakka\n   Tatriko\n  \n\n1 wak\n   Ernid\n  \n\n1 wak\n   Ubbe\n  \n\nSii nimmitetus Kr... | Tartu_V6nnu_Ahja_id21578_1867a
#  auto:  ...eme\n  \n\n2 wakka\n   Tatriko\n  \n\n1 wak\n   {Ernid} /PER\n  \n\n1 wak\n   Ubbe\n  \n\nSii nimmitetus Kr...
#
#  gold:  ... weel enne järrele mõttelda ja kindrali Froua käest küssida kuidas Kindrali Froua sel... | Harju_Hageri_Kohila_id10534_1871a
#  auto:  ... weel enne järrele mõttelda ja kindrali {Froua} /PER käest küssida kuidas Kindrali Froua sel...
#
#  gold:  ...ali Froua käest küssida kuidas Kindrali Froua sellega leppib, siis saad pärrast omma ... | Harju_Hageri_Kohila_id10534_1871a
#  auto:  ...ali Froua käest küssida kuidas Kindrali {Froua} /PER sellega leppib, siis saad pärrast omma ...
#
#  gold:  ...ust ilma tülida ja mina ei löönud teda. Homiku käis oma piibu järel mis õhtu minu wank... | J2rva_Tyri_V22tsa_id16489_1885a
#  auto:  ...ust ilma tülida ja mina ei löönud teda. {Homiku} /PER käis oma piibu järel mis õhtu minu wank...
#
#  gold:  ...Emma ilda aigo taggasi ärrakolnu ennamb Ilold kanda, päle too kui temma seinajani üll... | Tartu_V6nnu_Ahja_id9769_1871a
#  auto:  ...Emma ilda aigo taggasi ärrakolnu ennamb {Ilold} /PER kanda, päle too kui temma seinajani üll...
#
#  gold:  ...nistas et temma tulnud Mihkel Pihlagaga Jaamast maksusid maksmast ühhes koos, ja on sii... | Tartu_Torma_Avinurme_id23646_1872a
#  auto:  ...nistas et temma tulnud Mihkel Pihlagaga {Jaamast} /LOC maksusid maksmast ühhes koos, ja on sii...
#
#  gold:  ...ja ni om se haina kuhhu tassa saanu. Ja Jaan om tõisel päiwal essi 2 hobbesega perra... | V6ru_R2pina_Kahkva_id25279_1868a
#  auto:  ...ja ni om se haina kuhhu tassa saanu. Ja {Jaan} /PER om tõisel päiwal essi 2 hobbesega perra...
#
#  gold:  ...Tomson omma issa Tomas Tomsonile wälja. Jael Tomas Tomson annab poeale Jürrile Tündr... | Harju_Kose_Kose-Uuem6isa_id5178_1879a
#  auto:  ...Tomson omma issa Tomas Tomsonile wälja. {Jael} /PER Tomas Tomson annab poeale Jürrile Tündr...
#
#  gold:  ...Sel 28. Julil c. polele jänud asjus tulli Josep Nuggi... | Tartu_Kodavere_Alatskivi_id2193_1878a
#  auto:  ...Sel 28. {Julil} /PER c. polele jänud asjus tulli Josep Nuggi...
#
#  gold:  ...a Päiw peab tullewa Kohtopäiwas sel 22. Juni Kup. se Ostmisse Kontrakt ja nimmetud Tunni... | Tartu_V6nnu_Ahja_id11353_1872a
#  auto:  ...a Päiw peab tullewa Kohtopäiwas sel 22. {Juni Kup} /PER. se Ostmisse Kontrakt ja nimmetud Tunni...
#
#  gold:  ...das woib öölda, et Kirjutaja waletab.-\n\nKasak Johann Kolga ja tema naene tunnistasiwa... | Tartu_Kodavere_Alatskivi_id12579_1876a
#  auto:  ...das woib öölda, et Kirjutaja waletab.-\n\n{Kasak} /PER Johann Kolga ja tema naene tunnistasiwa...
#
#  gold:  ...hus kinnitab seda suusõnalist maha tegu Keisri Majesteti Ukasi järele walla kohtu ... | Harju_Jyri_Rae_id10721_1891a
#  auto:  ...hus kinnitab seda suusõnalist maha tegu {Ke} /ORGisri Majesteti Ukasi järele walla kohtu ...
#
#  gold:  ...\nNina küla majaperemehe ja Kingsepa Jakow Golubowi ja tema õpipoisi Ale... | Tartu_Kodavere_Alatskivi_id15341_1876a
#  auto:  ...\nNina küla majaperemehe ja {King} /LOC_ORGsepa Jakow Golubowi ja tema õpipoisi Ale...
#
#  gold:  ...ud, ja Jaan Alberti õuest teine, ja sai Kokko passitud Kohtu ees, et on Kustas Ekarju... | J2rva_Tyri_S2revere_id13629_1883a
#  auto:  ...ud, ja Jaan Alberti õuest teine, ja sai {Kokko} /LOC passitud Kohtu ees, et on Kustas Ekarju...
#
#  gold:  ...astu Pendimatsi karjamaad saab Jaanile. Koplist küla poolt pool saab Jürile, aga teine ... | Harju_Juuru_Kaiu_id925_1911a
#  auto:  ...astu Pendimatsi karjamaad saab Jaanile. {Koplist} /LOC küla poolt pool saab Jürile, aga teine ...
#
#  gold:  ... Wannamees kõrtzin käwwa om se Kott kas Kormast ärrawarrastetud saanu ehk Tee pääl mahh... | Tartu_V6nnu_Ahja_id21838_1868a
#  auto:  ... Wannamees kõrtzin käwwa om se Kott kas {Kormast} /PER ärrawarrastetud saanu ehk Tee pääl mahh...
#
#  gold:  ...e 5-ta Aprili\n\nkuust 1867. N´- 3. tulli Laenuause Jürri Selg kohtus\n\nja pallus, et temma ... | Viljandi_Viljandi_Karula_id19344_1867a
#  auto:  ...e 5-ta Aprili\n\nkuust 1867. N´- 3. tulli {Laenuause} /LOC_ORG Jürri Selg kohtus\n\nja pallus, et temma ...
#
#  gold:  ...urre andis ommast Kramist Johan Tällile Lainusses, selle et temma Issast perra jänu Kraam... | Tartu_V6nnu_Ahja_id21578_1867a
#  auto:  ...urre andis ommast Kramist Johan Tällile {Lainusses} /LOC, selle et temma Issast perra jänu Kraam...
#
#  gold:  ...Kirjutaja Karel Kasik\n\nTulli kohto ette Landrahti metsa waht Jürri Puuster ja kaebas Jürri Riom... | Harju_Juuru_Kaiu_id18871_1874a
#  auto:  ...Kirjutaja Karel Kasik\n\nTulli kohto ette {Landrahti metsa} /LOC waht Jürri Puuster ja kaebas Jürri Riom...
#
#  gold:  ...puudalt maksma, mis 7 Rubla wälja teeb. Landrati Härra ja Tallitaja on neid heinu järele... | J2rva_Ambla_Ambla_id6216_1889a
#  auto:  ...puudalt maksma, mis 7 Rubla wälja teeb. {Landrati} /LOC_ORG Härra ja Tallitaja on neid heinu järele...
#
#  gold:  ...i ette tunnistaja Liso Uibo Andre naine Lutteri usku ja ütles wälja et Peter Temo w... | V6ru_Vastseliina_Misso_id9268_1885a
#  auto:  ...i ette tunnistaja Liso Uibo Andre naine {Lut} /PERteri usku ja ütles wälja et Peter Temo w...
#
#  gold:  ...ilingut pesnü om.\n\nTunnistaja Jakob Sik Lutteri usku ütles wälja et mina ei ole mitte n... | V6ru_Vastseliina_Misso_id5473_1885a
#  auto:  ...ilingut pesnü om.\n\nTunnistaja Jakob Sik {Lutteri} /PER usku ütles wälja et mina ei ole mitte n...
#
#  gold:  ...demann XXX Jürri Reemann XXX\n\nKaebtus.\n\nMaggaski aidamees Jaan Sarmo kaebab et Tallitaja... | J2rva_Tyri_Kirna_id22642_1867a
#  auto:  ...demann XXX Jürri Reemann XXX\n\nKaebtus.\n\n{Maggaski} /LOC_ORG aidamees Jaan Sarmo kaebab et Tallitaja...
#
#  gold:  ...art Martok on minnewa küünlapääwa aegus Maggaskisse 16 Tsetwerikud tooreid rukkid ümber wah... | J2rva_Tyri_Kirna_id22642_1867a
#  auto:  ...art Martok on minnewa küünlapääwa aegus {Maggaskisse} /LOC_ORG 16 Tsetwerikud tooreid rukkid ümber wah...
#
#  gold:  ...lla puije eest 5 rubla hõbbedat massa.\n\nMan olliwa. Peakohtomees Josep Kerge\n\nAbbik... | Tartu_V6nnu_Kriimani_id9227_1863a
#  auto:  ...lla puije eest 5 rubla hõbbedat massa.\n\n{Man} /PER olliwa. Peakohtomees Josep Kerge\n\nAbbik...
#
#  gold:  ...a No 25 talu, mis Addawere wallas seisabMart Luik kätte täielikult ühe aastaks rendi peal... | Viljandi_P6ltsamaa_Adavere_id12307_1895a
#  auto:  ...a No 25 talu, mis Addawere wallas seisab{Mart Luik} /PER kätte täielikult ühe aastaks rendi peal...
#
#  gold:  ...a nenda:et Tomas Welti peab Jaan Piiril Marti peaval 1869 15 Rublat 66 1/2 Kop ja 28m... | Tartu_Kodavere_Pala_id21460_1869a
#  auto:  ...a nenda:et Tomas Welti peab Jaan Piiril {Marti} /PER peaval 1869 15 Rublat 66 1/2 Kop ja 28m...
#
#  gold:  ...t mõne muu viga pärast sündinud.\nOtsus.\nMetsakubjas\n"\n... | Tartu_R6ngu_Aakre_id2895_1888a
#  auto:  ...t mõne muu viga pärast sündinud.\nOtsus.\n{Metsa} /PERkubjas\n"\n...
#
#  gold:  ...ipeiwa selle  Aasta sees 17½ rbl. ningk Michlipeiwas Aasta perrast perrametze 17½ rbl. Rentp... | Tartu_R6ngu_Aakre_id13300_1828a
#  auto:  ...ipeiwa selle  Aasta sees 17½ rbl. ningk {Michlipeiwas} /PER Aasta perrast perrametze 17½ rbl. Rentp...
#
#  gold:  ...u jättap, siis aetasse teda seet welja, Ningk massap Kottar igga Aasta Kronu ningk Ko... | Tartu_R6ngu_Aakre_id12415_1827a
#  auto:  ...u jättap, siis aetasse teda seet welja, {Ningk} /PER massap Kottar igga Aasta Kronu ningk Ko...
#
#  gold:  ...mawad siss 3 Kubbu Ubbe warrastanu." Ka Nurm ollnud ülle Jöe ja läinud nemmad Wenneg... | Tartu_V6nnu_Ahja_id12382_1874a
#  auto:  ...mawad siss 3 Kubbu Ubbe warrastanu." Ka {Nurm} /PER ollnud ülle Jöe ja läinud nemmad Wenneg...
#
#  gold:  ...aan Naggel et kuwwe ajasta est om temma Nurme pält Ubbe warrastetud, ja nüüd om temma... | Tartu_V6nnu_Ahja_id12382_1874a
#  auto:  ...aan Naggel et kuwwe ajasta est om temma {Nurme} /LOC pält Ubbe warrastetud, ja nüüd om temma...
#
#  gold:  ...sohag ja ütleb et temma Lojosed nainud. Otsa heinama peale tullewad ülle niidetud he... | Harju_Hageri_Kohila_id23770_1872a
#  auto:  ...sohag ja ütleb et temma Lojosed nainud. {Otsa} /LOC heinama peale tullewad ülle niidetud he...
#
#  gold:  ...pois on juba 15 aastat täis 16ne peal). Plikka läinud pühapäeva õhtu 20 julil päwa loj... | Harju_Keila_Harku_id14716_1869a
#  auto:  ...pois on juba 15 aastat täis 16ne peal). {Plikka} /PER läinud pühapäeva õhtu 20 julil päwa loj...
#
#  gold:  ...Pujatust Mari Piir, nõumeheks Kusta Kustawson, a... | Viljandi_K6pu_Suure-K6pu_id6441_1884a
#  auto:  ...{Pujatust} /LOC Mari Piir, nõumeheks Kusta Kustawson, a...
#
#  gold:  ...haige olemisega ning and tunnistust, et Setukese Pognitsa Mik kes tema, Adam Suurmani kä... | V6ru_R2pina_Kahkva_id13937_1889a
#  auto:  ...haige olemisega ning and tunnistust, et {Setukese} /LOC_ORG Pognitsa Mik kes tema, Adam Suurmani kä...
#
#  gold:  ...a magasi mann om tulnud om Pognitsa Mik Setukese Adam Suurmannile üttelnud, et tema Pogn... | V6ru_R2pina_Kahkva_id13937_1889a
#  auto:  ...a magasi mann om tulnud om Pognitsa Mik {Setukese} /LOC_ORG Adam Suurmannile üttelnud, et tema Pogn...
#
#  gold:  ...op. wälja maksetud Kaani hääks, kellest Summast selle maatüki kolme aasta pruukimise ra... | Tartu_V6nnu_Ahja_id19400_1887a
#  auto:  ...op. wälja maksetud Kaani hääks, kellest {Summast} /PER selle maatüki kolme aasta pruukimise ra...
#
#  gold:  ... Bauer\n\nteine Jurri Luhha\n\nKarel Adolf\n\nSurema koh käimine sai kalutud.\n\n\n... | Tartu_Kursi_Puurmani_id23423_1874a
#  auto:  ... Bauer\n\nteine Jurri Luhha\n\nKarel Adolf\n\n{Surema koh} /LOC_ORG käimine sai kalutud.\n\n\n...
#
#  gold:  ...ollewat sedda nännu Michel Thalfeld.\n\nI T. Mölder Peter Kubi ütles et temma om sedda kogg... | V6ru_R6uge_Leevi_id25392_1875a
#  auto:  ...ollewat sedda nännu Michel Thalfeld.\n\nI {T. Mölder} /PER Peter Kubi ütles et temma om sedda kogg...
#
#  gold:  ... ja Päiw ollewad könnelnud, et se Weski Tamm peab katte õppinud Möldrida läbbi üllet... | Tartu_V6nnu_Ahja_id11353_1872a
#  auto:  ... ja Päiw ollewad könnelnud, et se Weski {Tamm} /PER peab katte õppinud Möldrida läbbi üllet...
#
#  gold:  ... jarrele jäda üks sadda rubla hõbbedad.\nTarrel jädaw likuw warra siis olli weel sesugg... | Tartu_Kodavere_Alatskivi_id13251_1856a
#  auto:  ... jarrele jäda üks sadda rubla hõbbedad.\n{Tarrel} /PER jädaw likuw warra siis olli weel sesugg...
#
#  gold:  ...            "                           Thomas Peterson\n\nKoggokonna nõumeisteks said wallitsetu... | Tartu_Laiuse_Kivij2rve_id13164_1866a
#  auto:  ...            "                           {Thomas Peterson} /PER\n\nKoggokonna nõumeisteks said wallitsetu...
#
#  gold:  ... suusõnalist maha tegu Keisri Majesteti Ukasi järele walla kohtu seadus 2. järgu §§ 2... | Harju_Jyri_Rae_id10721_1891a
#  auto:  ... suusõnalist maha tegu Keisri Majesteti {Ukasi} /PER järele walla kohtu seadus 2. järgu §§ 2...
#
#  gold:  ...nul ei ole mitte 12 rubl. 44 kop wölgu. Waid 7 rubla 27 kop. olin wölgu, aga selle w... | Viru_Iisaku_Iisaku_id2927_1885a
#  auto:  ...nul ei ole mitte 12 rubl. 44 kop wölgu. {Waid} /PER 7 rubla 27 kop. olin wölgu, aga selle w...
#
#  gold:  ...rn ja Karel Sep et\n\ntemma järrele jänut Warrantus mis selle süggise arwatut Inna jä... | Tartu_Kodavere_Pala_id18128_1862a
#  auto:  ...rn ja Karel Sep et\n\ntemma järrele jänut {War} /PERrantus mis selle süggise arwatut Inna jä...
#
#  gold:  ...\n\n23.) 2 Õhvat \n   13 Rublad\n  \n\n24.) 1 Wassik\n     2 Rublad\n  \n\n                     ... | Tartu_Kodavere_Pala_id22036_1870a
#  auto:  ...\n\n23.) 2 Õhvat \n   13 Rublad\n  \n\n24.) 1 {Wassik} /PER\n     2 Rublad\n  \n\n                     ...
#
#  gold:  ...er Prätsile ehk wimate Jaan Hussarile.\n(Witok ........)\nEt se lepping nida om sündinu... | V6ru_R6uge_Saaluse_id11774_1880a
#  auto:  ...er Prätsile ehk wimate Jaan Hussarile.\n({Witok} /PER ........)\nEt se lepping nida om sündinu...
#
#  gold:  ...i Tupai leikamatta rukki ärrasussinud.3.Wõrku sead on Tupai niitmatta heinamaad 3at k... | Harju_Kose_Palvere_id17520_1882a
#  auto:  ...i Tupai leikamatta rukki ärrasussinud.3.{Wõrku} /LOC_ORG sead on Tupai niitmatta heinamaad 3at k...
#
#  gold:  ...s ja õe Maria Elisabeth Johansile (kumbagile) nüüd mehe järele Idla, kumbagile üks s... | J2rva_Tyri_Tyri-Alliku_id3270_1901a
#  auto:  ...s ja õe Maria Elisabeth Johansile (kumba{gile} /PER) nüüd mehe järele Idla, kumbagile üks s...
#
#  gold:  ... koggokonna kohhus sel\nxxx Jaan Seba koggokonna kohtu pea\nxxx Peter Nikopensius ko... | V6ru_P6lva_K2hri_id21539_1850a
#  auto:  ... koggokonna kohhus sel\nxxx Jaan Seba kog{go} /ORGkonna kohtu pea\nxxx Peter Nikopensius ko...
#
#  gold:  ... Känd.\n\nTalitaja ja Metsa waht on puud Kini pand, et saab Kustase jägo wälja arwatu... | J2rva_Tyri_S2revere_id13629_1883a
#  auto:  ... Känd.\n\nTalitaja ja Metsa waht on puud K{ini} /PER pand, et saab Kustase jägo wälja arwatu...
#
#  gold:  ...uu viga pärast sündinud.\nOtsus.\nMetsakubjas\n"\n... | Tartu_R6ngu_Aakre_id2895_1888a
#  auto:  ...uu viga pärast sündinud.\nOtsus.\nMetsakub{jas} /PER\n"\n...
#
#  gold:  ...e muu viga pärast sündinud.\nOtsus.\nMetsakubjas\n"\n... | Tartu_R6ngu_Aakre_id2895_1888a
#  auto:  ...e muu viga pärast sündinud.\nOtsus.\nMetsa{kub} /LOC_ORGjas\n"\n...
#
#  gold:  ... Wiina saanu ja arwas: et kui Wannamees kõrtzin käwwa om se Kott kas Kormast ärrawarras... | Tartu_V6nnu_Ahja_id21838_1868a
#  auto:  ... Wiina saanu ja arwas: et kui Wannamees {kõrtzin} /PER käwwa om se Kott kas Kormast ärrawarras...
#
#  gold:  ...e mõistetud, siis ei wöi tema ka midagi podrätsiko Grendini käest nöuda.\n\nPeter Kripson XX... | Tartu_V6nnu_Ahja_id13367_1881a
#  auto:  ...e mõistetud, siis ei wöi tema ka midagi {podrätsiko} /LOC_ORG Grendini käest nöuda.\n\nPeter Kripson XX...
#
#  gold:  ...ja Karel Sep et\n\ntemma järrele jänut Warrantus mis selle süggise arwatut Inna järrel 1... | Tartu_Kodavere_Pala_id18128_1862a
#  auto:  ...ja Karel Sep et\n\ntemma järrele jänut War{rantus} /LOC mis selle süggise arwatut Inna järrel 1...
#
#  gold:  ...öisale maksta tulleb, se on 3 tündrid Otri, ja 2 tündrid kaeru (Wannad Tallinna tü... | Harju_Kose_Kose-Uuem6isa_id5178_1879a
#  auto:  ...öisale maksta tulleb, se on 3 tündrid Ot{ri} /PER, ja 2 tündrid kaeru (Wannad Tallinna tü...
#
#  gold:  ...bi Josep Leppasep\n\nabbi Josep Wenne\n\nJa saksa metsa waht Pärding ja temma abbi Said metsa s... | Tartu_Kodavere_Ranna_id14148_1855a
#  auto:  ...bi Josep Leppasep\n\nabbi Josep Wenne\n\nJa {saksa metsa} /LOC waht Pärding ja temma abbi Said metsa s...
#
#  gold:  ...\n\n/:Otsus kulutud sel 15. Decembril. c. seaduse ramato §§ N2 ja N3 juhhatusel, ja oppuse kirja... | Tartu_Kodavere_Alatskivi_id3879_1878a
#  auto:  ...\n\n/:Otsus kulutud sel 15. Decembril. c. {seaduse ramato} /MISC §§ N2 ja N3 juhhatusel, ja oppuse kirja...
#
#  gold:  ...le ja Jaan Keksile  ni kui se on kästud walla kohtu seaduses 9. Julist 1889. a Kohto istumisel täies... | Viljandi_P6ltsamaa_Adavere_id19457_1892a
#  auto:  ...le ja Jaan Keksile  ni kui se on kästud {walla kohtu seaduses} /MISC 9. Julist 1889. a Kohto istumisel täies...
#
#  gold:  ... II aasta krono pearaha sisse korjata Riwisionis on järrel 291 hinge ja igga nende hinge... | L22ne_Kullamaa_Piirsalu_id7160_1880a
#  auto:  ... II aasta krono pearaha sisse korjata Ri{wisionis} /PER on järrel 291 hinge ja igga nende hinge...
#
#  gold:  ...mõistmisega rahul, waid nõudis oma asja Ülema Talurahwa kohtu ette wiia.\n\nKohtu w... | Harju_Hageri_Kohila_id5581_1890a
# ...
#  auto:  ... Temmal olnud tollest päest ärra, Naine Katto josknu Abbi ostma ja tulnu kutsumisse p...
#
#  gold:  ....\n\nJüri Tippi ütleb ennast 25 1/2 päewa {Kiriku} /PER all tööl olnud ja kauplesin 50 kopikat ... | J2rva_Ambla_Ambla_id7566_1888a
#  auto:  ....\n\nJüri Tippi ütleb ennast 25 1/2 päewa Kiriku all tööl olnud ja kauplesin 50 kopikat ...
#
#  gold:  ...\nKaibas Suitzo Peter, {Kirriko Wallast} /LOC_ORG, et Wösmi Pedo ja Märt Michelson, Ahjas... | Tartu_V6nnu_Ahja_id21838_1868a
#  auto:  ...\nKaibas Suitzo Peter, Kirriko Wallast, et Wösmi Pedo ja Märt Michelson, Ahjas...
#
#  gold:  ...tmisse Kontrakt ja nimmetud Tunnistajad {Kohler} /PER ja Tölksep ütten tooma, ni kui ei kah K... | Tartu_V6nnu_Ahja_id11353_1872a
#  auto:  ...tmisse Kontrakt ja nimmetud Tunnistajad Kohler ja Tölksep ütten tooma, ni kui ei kah K...
#
#  gold:  ...nemaale Maa Ostmissest weel peab saama.\n{Küttipeter} /LOC_ORG Michel ettekutsutud jaselle Assja perra... | Tartu_V6nnu_Ahja_id9067_1871a
#  auto:  ...nemaale Maa Ostmissest weel peab saama.\nKüttipeter Michel ettekutsutud jaselle Assja perra...
#
#  gold:  ...ma, et kui palju on möldri maad üle tee {Laiba kapsa aja} /LOC sees, maa mõõtja on kaartist waadanud j... | Harju_Jyri_Rae_id6623_1890a
#  auto:  ...ma, et kui palju on möldri maad üle tee Laiba kapsa aja sees, maa mõõtja on kaartist waadanud j...
#
#  gold:  ...õtja on kaartist waadanud ja öölnud: et {Laiba kuhal} /LOC_ORG üle tee maad ei ole, sest se maa tük on... | Harju_Jyri_Rae_id6623_1890a
#  auto:  ...õtja on kaartist waadanud ja öölnud: et Laiba kuhal üle tee maad ei ole, sest se maa tük on...
#
#  gold:  ...rja wanduma ja ütelnud laimates Reinule:{Leistu} /LOC_ORG koer oled ja juba kolm aastat olnud ja ... | Harju_Kose_Palvere_id23829_1887a
#  auto:  ...rja wanduma ja ütelnud laimates Reinule:Leistu koer oled ja juba kolm aastat olnud ja ...
#
#  gold:  ...\n{Leping\n\nAstus kohtu ette Mihkel Kirschberg} /PER ja Jakob Lettens ning palusid järgmisel... | Viljandi_P6ltsamaa_Adavere_id17425_1894a
#  auto:  ...\nLeping\n\nAstus kohtu ette Mihkel Kirschberg ja Jakob Lettens ning palusid järgmisel...
#
#  gold:  ...eisega seddä modo lepno nemmad om kokko {Lokkotaja} /LOC Lätte mäe krundi wõi tallo ostno 10 tad... | V6ru_R2pina_R2pina_id10305_1870a
#  auto:  ...eisega seddä modo lepno nemmad om kokko Lokkotaja Lätte mäe krundi wõi tallo ostno 10 tad...
#
#  gold:  ...\nJakobi Jaen 10 ---\n\nMatsimardi 20 ---\n\n{Metwawahhi} /LOC_ORG 5 ---\n\nMaltsiwetti 5 ---\n\nSeppa Tönno 5... | J2rva_J2rva-Jaani_Einmanni_id9824_1868a
#  auto:  ...\nJakobi Jaen 10 ---\n\nMatsimardi 20 ---\n\nMetwawahhi 5 ---\n\nMaltsiwetti 5 ---\n\nSeppa Tönno 5...
#
#  gold:  ...Karl Põlgas Wastselinast ütles wälja et {Mokra} /PER tulli sisse ja küsis pool kortina wina ... | V6ru_Vastseliina_Misso_id13403_1881a
#  auto:  ...Karl Põlgas Wastselinast ütles wälja et Mokra tulli sisse ja küsis pool kortina wina ...
#
#  gold:  ...õrtsimees laskis nink nõudse 6 Kop. ent {Mokra} /PER massis enne 5 Kop. nink sest tulli se t... | V6ru_Vastseliina_Misso_id13403_1881a
#  auto:  ...õrtsimees laskis nink nõudse 6 Kop. ent Mokra massis enne 5 Kop. nink sest tulli se t...
#
#  gold:  ...sinnä nink sis tõugati minno wälja nink {Mokra} /PER jätteti sisse nink nakkas tänni nink si... | V6ru_Vastseliina_Misso_id13403_1881a
#  auto:  ...sinnä nink sis tõugati minno wälja nink Mokra jätteti sisse nink nakkas tänni nink si...
#
#  gold:  ...Janit ent Karl Jurgis es olle joht sääl {Mokra} /PER säljan enge saisis kõrwal nink Mokra la... | V6ru_Vastseliina_Misso_id13403_1881a
#  auto:  ...Janit ent Karl Jurgis es olle joht sääl Mokra säljan enge saisis kõrwal nink Mokra la...
#
#  gold:  ...äl Mokra säljan enge saisis kõrwal nink {Mokra} /PER larmitses et se ei olle pool nakla et a... | V6ru_Vastseliina_Misso_id13403_1881a
#  auto:  ...äl Mokra säljan enge saisis kõrwal nink Mokra larmitses et se ei olle pool nakla et a...
#
#  gold:  ... keppiga perrast aijewa meid wälja nink {Mokra} /PER tännit et appi ärra tappetas ent lömist... | V6ru_Vastseliina_Misso_id13403_1881a
#  auto:  ... keppiga perrast aijewa meid wälja nink Mokra tännit et appi ärra tappetas ent lömist...
#
#  gold:  ...er Piir ütles wälja et nemma larmitsiwa {Mokraga} /PER selle ütte keppiga perrast aijewa meid ... | V6ru_Vastseliina_Misso_id13403_1881a
#  auto:  ...er Piir ütles wälja et nemma larmitsiwa Mokraga selle ütte keppiga perrast aijewa meid ...
#
#  gold:  ...pesnud. Kristian Weisner ei olle tulnu.\n{Möldre} /MISC Janit ka ei olle tulnu.\nOtto Pakkis ütl... | V6ru_Vastseliina_Misso_id13403_1881a
#  auto:  ...pesnud. Kristian Weisner ei olle tulnu.\nMöldre Janit ka ei olle tulnu.\nOtto Pakkis ütl...
#
#  gold:  ...wälja tulnud ja jahho ja erneid toond.\n\n{Nuttu} /LOC_ORG rentnik on leind et temma aitas olli kä... | Harju_Kose_Triigi_id9934_1870a
#  auto:  ...wälja tulnud ja jahho ja erneid toond.\n\nNuttu rentnik on leind et temma aitas olli kä...
#
#  gold:  ...d wankre rattast. jahhud ja erned on ta {Nuttu aidast} /LOC wötnud ja rattad oue pealt, jahho on ta... | Harju_Kose_Triigi_id9934_1870a
#  auto:  ...d wankre rattast. jahhud ja erned on ta Nuttu aidast wötnud ja rattad oue pealt, jahho on ta...
#
#  gold:  ...a kaebab et Rasi perremehhel 11. lojust {Prosol} /MISC 2. Allika Jakobi\n\n2. Seasel 2. Orro Kus... | Harju_Hageri_Kohila_id23770_1872a
#  auto:  ...a kaebab et Rasi perremehhel 11. lojust Prosol 2. Allika Jakobi\n\n2. Seasel 2. Orro Kus...
#
#  gold:  ...Karl Kohler ja Adam Tölksepp sia tooma, {Päiw} /PER ettekutsutud ja Ostmisse Kontraktid küs... | Tartu_V6nnu_Ahja_id11353_1872a
#  auto:  ...Karl Kohler ja Adam Tölksepp sia tooma, Päiw ettekutsutud ja Ostmisse Kontraktid küs...
#
#  gold:  ...ullema, pallel üllestähendada, et temma {Päiwa} /PER perrast, kea mitte Ostmisse Kontrakti j... | Tartu_V6nnu_Ahja_id11353_1872a
#  auto:  ...ullema, pallel üllestähendada, et temma Päiwa perrast, kea mitte Ostmisse Kontrakti j...
#
#  gold:  ...ohtu ette ja kaebab mina olin 11. päewa {Rawa möldri toa} /LOC juures tööl ja pidin 55 kopikat päewas ... | J2rva_Ambla_Ambla_id7566_1888a
#  auto:  ...ohtu ette ja kaebab mina olin 11. päewa Rawa möldri toa juures tööl ja pidin 55 kopikat päewas ...
#
#  gold:  ...n on ülesse pandud. Ja wõiwad seda raha {Rawale} /LOC kinni panna kui seal weel sees on.\n\ntäi... | J2rva_Ambla_Ambla_id7566_1888a
#  auto:  ...n on ülesse pandud. Ja wõiwad seda raha Rawale kinni panna kui seal weel sees on.\n\ntäi...
#
#  gold:  ...ma ütlen ka kust ma need linnud wõtsin. {Rheder} /PER ütles: Sina isi oled wiinud.\n\nSiis kuul... | Harju_Hageri_Kohila_id3159_1885a
#  auto:  ...ma ütlen ka kust ma need linnud wõtsin. Rheder ütles: Sina isi oled wiinud.\n\nSiis kuul...
#
#  gold:  ...a rentnikule hagu anda\n\n8. rentnik peab {Saawa palo} /LOC_ORG teejagu tegema\n\n9. rentnik peab oma kat... | Tartu_V6nnu_Ahja_id23171_1892a
#  auto:  ...a rentnikule hagu anda\n\n8. rentnik peab Saawa palo teejagu tegema\n\n9. rentnik peab oma kat...
#
#  gold:  ...rra aianud, siis ei polleks sinna mitte {Sehwre} /PER aiamisse peale ärraminnema piddanud. Nü... | Harju_Hageri_Kohila_id10534_1871a
#  auto:  ...rra aianud, siis ei polleks sinna mitte Sehwre aiamisse peale ärraminnema piddanud. Nü...
#
#  gold:  ...eest Elistwere maksnud 12 rubla 55 Kop, {Sotniku} /PER palk 90 Kop, Kiriku wöörmündrile 30 Kop... | Tartu_Kodavere_Alatskivi_id15341_1876a
#  auto:  ...eest Elistwere maksnud 12 rubla 55 Kop, Sotniku palk 90 Kop, Kiriku wöörmündrile 30 Kop...
#
#  gold:  ...\n{Tarwastu} /LOC Mustla Kõrtsiissad H.Robensee astus ett... | Viljandi_Tarvastu_Tarvastu_id4042_1875a
#  auto:  ...\nTarwastu Mustla Kõrtsiissad H.Robensee astus ett...
#
#  gold:  ... kukro peale.\n\nTunnistaja Andres Roosen/{Tarwastu} /LOC/ tunnistas nenda sama kui Märt Wain.\n\nM... | Viljandi_Tarvastu_Tarvastu_id4042_1875a
#  auto:  ... kukro peale.\n\nTunnistaja Andres Roosen/Tarwastu/ tunnistas nenda sama kui Märt Wain.\n\nM...
#
#  gold:  ...ngimise eest kinni ehk maksab 4 Rbl höb {Tarwastu} /LOC_ORG waeste laekase trahvi.\n\nSee möistus sai... | Viljandi_Tarvastu_Tarvastu_id4042_1875a
#  auto:  ...ngimise eest kinni ehk maksab 4 Rbl höb Tarwastu waeste laekase trahvi.\n\nSee möistus sai...
#
#  gold:  ...trakt ja nimmetud Tunnistajad Kohler ja {Tölksep} /PER ütten tooma, ni kui ei kah Kohler siss ... | Tartu_V6nnu_Ahja_id11353_1872a
#  auto:  ...trakt ja nimmetud Tunnistajad Kohler ja Tölksep ütten tooma, ni kui ei kah Kohler siss ...
#
#  gold:  ... Jael Tomas Tomson annab poeale Jürrile {Tündreseppa maja} /LOC_ORG pöhjaks mis möisale maksta tulleb, se o... | Harju_Kose_Kose-Uuem6isa_id5178_1879a
#  auto:  ... Jael Tomas Tomson annab poeale Jürrile Tündreseppa maja pöhjaks mis möisale maksta tulleb, se o...
#
#  gold:  ...as 300 Rubla sellele kes wälla lähheb.  {Wido} /PER om Jakobil andno 6 Lehma 1 hobbene 3 Si... | V6ru_R2pina_R2pina_id10305_1870a
#  auto:  ...as 300 Rubla sellele kes wälla lähheb.  Wido om Jakobil andno 6 Lehma 1 hobbene 3 Si...
#
#  gold:  ...d 3 rubla 90Koppikat ette ja 10 pudelid {bairich õlut} /MISC kaasa wiinud wenese ja siis  wennaga är... | Tartu_Kodavere_Alatskivi_id15625_1876a
#  auto:  ...d 3 rubla 90Koppikat ette ja 10 pudelid bairich õlut kaasa wiinud wenese ja siis  wennaga är...
#
#  gold:  ...ed ööd olnud temma omma sugulaste jures {liwalaia ulitsas} /LOC Jüri kamaes Nüüd küsiti weel kui kaua s... | Harju_Keila_Harku_id14723_1869a
#  auto:  ...ed ööd olnud temma omma sugulaste jures liwalaia ulitsas Jüri kamaes Nüüd küsiti weel kui kaua s...
#
#  gold:  ...ahhud olli ta puhhas ärra söönd sest et {nuttu} /LOC_ORG rentnik kohe ei leidnud kui sai warrast... | Harju_Kose_Triigi_id9934_1870a
#  auto:  ...ahhud olli ta puhhas ärra söönd sest et nuttu rentnik kohe ei leidnud kui sai warrast...
#
#  gold:  ...l maade wastu seda inventari olema, mis {talurahwa sead.} /MISC 1860 aastast kinnitud on. Loomi peab te... | Viljandi_P6ltsamaa_Adavere_id17466_1894a
#  auto:  ...l maade wastu seda inventari olema, mis talurahwa sead. 1860 aastast kinnitud on. Loomi peab te...
#
#  gold:  ...maha tegu Keisri Majesteti Ukasi järele {walla kohtu seadus} /MISC 2. järgu §§ 278 ja 282 põhja peal, et n... | Harju_Jyri_Rae_id10721_1891a
#  auto:  ...maha tegu Keisri Majesteti Ukasi järele walla kohtu seadus 2. järgu §§ 278 ja 282 põhja peal, et n...
#
#  gold:  ...llakirjutanud sellepärast on see leping {wallakohtu sead} /MISC II jao § 282 põhjusel No 4 al akti rama... | Viljandi_P6ltsamaa_Adavere_id17425_1894a
#  auto:  ...llakirjutanud sellepärast on see leping wallakohtu sead II jao § 282 põhjusel No 4 al akti rama...
#
#  gold:  ...se maa tük seisab N 4 all ja Kiiwita ja {wesgi õue krunt} /LOC_ORG on mõlematel N 4 all lantkaartis. \n\nJää... | Harju_Jyri_Rae_id6623_1890a
#  auto:  ...se maa tük seisab N 4 all ja Kiiwita ja wesgi õue krunt on mõlematel N 4 all lantkaartis. \n\nJää...
#
#
# ======================================================================
# wrong_boundaries + wrong_label (20)
# ======================================================================
#  gold:  ... on temmale lubba antud omma ellajatega {Ermanni} /PER krunti peal käia.\n\nMoisa polest sai tun... | J2rva_Tyri_Kirna_id23074_1871a
#  auto:  ... on temmale lubba antud omma ellajatega {Ermanni krunti} /LOC_ORG peal käia.\n\nMoisa polest sai tunnistadu...
#
#  gold:  ...mis on Jaan Aripowe kaest mahha om jänu {Grenztali} /PER maa pale jätta ja sedda aja maad mis ta... | V6ru_R2pina_R2pina_id12449_1866a
#  auto:  ...mis on Jaan Aripowe kaest mahha om jänu {Grenztali maa} /LOC_ORG pale jätta ja sedda aja maad mis tarre ...
#
#  gold:  ...Jeger on minule kuus (6) rubl. 30 cop.  {Iisaku kugu} /LOC_ORG välgu. Kohtu küsimiste peale, kas sina ... | Viru_Iisaku_Iisaku_id2910_1885a
#  auto:  ...Jeger on minule kuus (6) rubl. 30 cop.  {Iisaku} /LOC kugu välgu. Kohtu küsimiste peale, kas ...
#
#  gold:  ...s Klauberg olla Paide kõrtsis ja pärast {Koigi Poe} /LOC_ORG ees lassingi ääres rääkinud, et Andres ... | J2rva_Tyri_S2revere_id6495_1883a
#  auto:  ...s Klauberg olla Paide kõrtsis ja pärast {Koigi} /ORG Poe ees lassingi ääres rääkinud, et And...
#
#  gold:  ...kkeldi walla mees Hans Pädam,et tema on {Kolowerre ladal} /MISC Sikkeldi lamba sihwre hobbose ärra münu... | Harju_Rapla_Rapla_id24000_1873a
#  auto:  ...kkeldi walla mees Hans Pädam,et tema on {Kolowerre} /LOC ladal Sikkeldi lamba sihwre hobbose ärr...
#
#  gold:  ...llu saab selletud saama.\nSai moistetud: {Küttipeter} /LOC_ORG Michel ei pruki Jaan Birkenbaumile enne... | Tartu_V6nnu_Ahja_id9067_1871a
#  auto:  ...llu saab selletud saama.\nSai moistetud: {Küttipe} /MISCter Michel ei pruki Jaan Birkenbaumile e...
#
#  gold:  ...jutaja Thomson astus ette ja kaebas, et {Laheperra} /LOC-sepp Johann Johanson ajanud minewa püha... | Tartu_Kodavere_Alatskivi_id12579_1876a
#  auto:  ...jutaja Thomson astus ette ja kaebas, et {Laheperra-} /MISCsepp Johann Johanson ajanud minewa pühap...
#
#  gold:  ...eda maad mis tema lauda taga on üle tee {Laiba aja} /LOC sees, mis möldri jagu on ja küsinud kus... | Harju_Jyri_Rae_id6623_1890a
#  auto:  ...eda maad mis tema lauda taga on üle tee {Laiba} /LOC_ORG aja sees, mis möldri jagu on ja küsinud...
#
#  gold:  ...t tulid,mõistis k.temale 1 rubla trahwi {P.} /LOC_ORGw.laeka.\n\n\n... | Harju_Kose_Palvere_id23829_1887a
#  auto:  ...t tulid,mõistis k.temale 1 rubla trahwi {P.w.} /PERlaeka.\n\n\n...
#
#  gold:  ...ga! mõistis kohus temale,1 rubla trahwi {Palw.} /LOC_ORGw.l.\n\nII Et Hans Poomann seda õunawargus... | Harju_Kose_Palvere_id23829_1887a
#  auto:  ...ga! mõistis kohus temale,1 rubla trahwi {Pal} /ORGw.w.l.\n\nII Et Hans Poomann seda õunawarg...
#
#  gold:  ...stumäe küla pool saab Jürile, aga wastu {Pendimatsi karjamaad} /LOC saab Jaanile. Koplist küla poolt pool s... | Harju_Juuru_Kaiu_id925_1911a
#  auto:  ...stumäe küla pool saab Jürile, aga wastu {Pendimatsi} /LOC_ORG karjamaad saab Jaanile. Koplist küla po...
#
#  gold:  ...,need on Jaan Sein ja Eerik,meie tuleme {Reinu} /PER rohuajast.Jaan ja Erik käisid puu otsas... | Harju_Kose_Palvere_id23829_1887a
#  auto:  ...,need on Jaan Sein ja Eerik,meie tuleme {Reinu rohu} /LOCajast.Jaan ja Erik käisid puu otsas ja m...
#
#  gold:  ...\nÄrakiri\n\n{Saawa} /LOC_ORG Johan Saawa on ära koolnud ja sai koguk... | Tartu_V6nnu_Ahja_id22725_1880a
#  auto:  ...\nÄrakiri\n\n{Saa} /PERwa Johan Saawa on ära koolnud ja sai kog...
#
#  gold:  ...õime mõisast korra tutrukud kodu, ja 1, {Sorsa wabriku} /LOC pois hakkas tüdrukuid näppima: Kõrtsmik... | Harju_Kuusalu_K6nnu_id14450_1880a
#  auto:  ...õime mõisast korra tutrukud kodu, ja 1, {Sorsa} /LOC_ORG wabriku pois hakkas tüdrukuid näppima: ...
#
#  gold:  ... wasto wahetud.Ja et Wõrko sead 3 korda {Tupai} /PER niitmata heinamaad tustinud,iggakord 6 ... | Harju_Kose_Palvere_id17520_1882a
#  auto:  ...asto wahetud.Ja et Wõrko sead 3 korda Tu{pai} /LOC niitmata heinamaad tustinud,iggakord 6 ...
#
#  gold:  ... Wanaku koha seemet rukki põllu tarwis. {Wanaku kohal} /LOC_ORG on 14 tiinu põldu, 1/3 sest om 4 1/3 tä... | Harju_Hageri_Kohila_id5581_1890a
#  auto:  ... Wanaku koha seemet rukki põllu tarwis. {Wanaku} /LOC kohal on 14 tiinu põldu, 1/3 sest om 4 ...
#
#  gold:  ... 1/3 sest om 4 1/3 tänu, siis on terwel {Wanaku kohal} /LOC_ORG 26 wakamaad rukki maad. 1/2 sest on 13 ... | Harju_Hageri_Kohila_id5581_1890a
#  auto:  ... 1/3 sest om 4 1/3 tänu, siis on terwel {Wanaku} /LOC kohal 26 wakamaad rukki maad. 1/2 sest ...
#
#  gold:  ...wallalaeka maksma.2.Et Kingsepa weiksed {Wõrgo} /PER heinas olnud peab Kingsep igga looma pe... | Harju_Kose_Palvere_id17520_1882a
#  auto:  ...wallalaeka maksma.2.Et Kingsepa weiksed {Wõrgo heinas} /LOC olnud peab Kingsep igga looma pealt 20 ...
#
#  gold:  ... tehtud s.o. esimene lubab wiimase rudi {talu Erne} /LOC_ORG N: 44 maa pääle ühe elumaja üles ehitad... | Tartu_V6nnu_Ahja_id4253_1907a
#  auto:  ...ud s.o. esimene lubab wiimase rudi talu {Erne} /PER N: 44 maa pääle ühe elumaja üles ehitad...
#
#  gold:  ...ma elumaja ilma vastuvaidlemata nimitud {talu Erne} /LOC_ORG N: 44 maa pealt maha lahkuma ja ära wii... | Tartu_V6nnu_Ahja_id4253_1907a
#  auto:  ...umaja ilma vastuvaidlemata nimitud talu {Erne} /PER N: 44 maa pealt maha lahkuma ja ära wii...
#
#
#  Evaluated on 250 documents.

# %% [markdown]
# ---
